# %%
import pandas as pd
import psycopg2
from dotenv import load_dotenv
import os

# Load environment variables from secret.env
load_dotenv(dotenv_path='secret.env', override=True)

# Get database credentials from environment variables
DB_NAME = os.getenv('DB_NAME')
DB_USER = os.getenv('DB_USER')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_HOST = os.getenv('DB_HOST')

# Connect to the database
conn = psycopg2.connect(
    dbname=DB_NAME, 
    user=DB_USER, 
    password=DB_PASSWORD, 
    host=DB_HOST
)

# Execute the query to fetch data from processed_urls
query = """
SELECT * FROM processed_urls;
"""
df_processed_urls = pd.read_sql(query, conn)

# Close the connection
conn.close()

# Display the fetched data
df_processed_urls
# Out:
#     id                                                url  match_id  \
# 0    1  https://www.whoscored.com/Matches/1787315/Live...   1787315
# 1    2  https://www.whoscored.com/Matches/1787328/Live...   1787328
# 2    3  https://www.whoscored.com/Matches/1787317/Live...   1787317
# 3    4  https://www.whoscored.com/Matches/1787330/Live...   1787330
# 4    5  https://www.whoscored.com/Matches/1812235/Live...   1812235
# 5    6  https://www.whoscored.com/Matches/1787319/Live...   1787319
# 6    7  https://www.whoscored.com/Matches/1787334/Live...   1787334
# 7    8  https://www.whoscored.com/Matches/1812234/Live...   1812234
# 8    9  https://www.whoscored.com/Matches/1787323/Live...   1787323
# 9   10  https://www.whoscored.com/Matches/1787312/Live...   1787312
# 10  11  https://www.whoscored.com/Matches/1812181/Live...   1812181
# 11  12  https://www.whoscored.com/Matches/1787325/Live...   1787325
# 12  13  https://www.whoscored.com/Matches/1787318/Live...   1787318
# ...
